# %%
# %load_ext autoreload
# %autoreload 2

# %%
# %matplotlib inline
from Regard import init, Data

args = init(batch_size=16, verbose=1)
#args.batch_size=16
d = Data(args)
fig, ax = d.show()
# Out:
# cuda? False

# %%
from Regard import ML

ml = ML(args)
ml.device
# Out:
# cuda? False
# cuda? False
# device(type='cpu')

# %% [markdown]
# ## running the model

# %%
for batch_idx, (data, target) in enumerate(ml.d.train_loader):
    data, target = data.to(ml.device), target.to(ml.device)
    output = ml.model(data)

# %% [markdown]
# ## learning the model

# %%
ml.main()
# Out:
# Train Epoch: 1
# 	Train Epoch: 1 [0/459 (0%)]	Loss: 1.404857
# 	Train Epoch: 1 [160/459 (34%)]	Loss: 1.014209
# 	Train Epoch: 1 [320/459 (69%)]	Loss: 1.051974
# Train Epoch: 2
# 	Train Epoch: 2 [0/459 (0%)]	Loss: 1.146292
# 	Train Epoch: 2 [160/459 (34%)]	Loss: 0.907084
# 	Train Epoch: 2 [320/459 (69%)]	Loss: 0.995459
# Train Epoch: 3
# 	Train Epoch: 3 [0/459 (0%)]	Loss: 1.107519
# 	Train Epoch: 3 [160/459 (34%)]	Loss: 0.855620
# 	Train Epoch: 3 [320/459 (69%)]	Loss: 0.955210
# Train Epoch: 4
# 	Train Epoch: 4 [0/459 (0%)]	Loss: 1.061193
# 	Train Epoch: 4 [160/459 (34%)]	Loss: 0.812075
# 	Train Epoch: 4 [320/459 (69%)]	Loss: 0.843921
# Train Epoch: 5
# 	Train Epoch: 5 [0/459 (0%)]	Loss: 1.084098
# 	Train Epoch: 5 [160/459 (34%)]	Loss: 0.770712
# 	Train Epoch: 5 [320/459 (69%)]	Loss: 0.822942
# Train Epoch: 6
# 	Train Epoch: 6 [0/459 (0%)]	Loss: 0.999929
# 	Train Epoch: 6 [160/459 (34%)]	Loss: 0.811006
# 	Train Epoch: 6 [320/459 (69%)]	Loss: 1.004374
# Train Epoch: 7

# %% [markdown]
# ## testing the model

# %%
ml.test()

# %%
data, labels = next(iter(ml.d.train_loader))
print(' '.join('%5s' % ml.d.classes[labels[j]] for j in range(ml.args.batch_size)))

# %%
ml.show()
